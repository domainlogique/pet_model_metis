# %%
import pandas as pd # To load in one of the functionality that pandas provides (import pandas as pd)
import numpy as np # To load additional functionality and package that pandas relies on called NumPy (import numpy as np)
import category_encoders as ce
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures, StandardScaler
from sklearn.linear_model import Lasso, Ridge, LinearRegression, LogisticRegression, ElasticNet
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn import metrics
from sklearn.cross_validation import cross_val_score, train_test_split
import scipy.stats as stats

# %%
pTrain = pd.read_csv("../data/pTrain.csv") #To read in the Dataset; note changed xlsx to csv
pTrain.DateTime = pd.to_datetime(pTrain.DateTime) #To make date/time readable

# %%
#Let's take a look at the first few rows of data
pTrain.head()
# Out:
#   AnimalID     Name            DateTime      OutcomeType AnimalType  \
# 0  A671945  Hambone 2014-02-12 18:22:00  Return_to_owner        Dog
# 1  A656520    Emily 2013-10-13 12:44:00       Euthanasia        Cat
# 2  A686464   Pearce 2015-01-31 12:28:00         Adoption        Dog
# 3  A683430      NaN 2014-07-11 19:09:00         Transfer        Cat
# 4  A667013      NaN 2013-11-15 12:52:00         Transfer        Dog
#
#   SexuponOutcome AgeuponOutcome                        Breed        Color
# 0  Neutered Male         1 year        Shetland Sheepdog Mix  Brown/White
# 1  Spayed Female         1 year       Domestic Shorthair Mix  Cream Tabby
# 2  Neutered Male        2 years                 Pit Bull Mix   Blue/White
# 3    Intact Male        3 weeks       Domestic Shorthair Mix   Blue Cream
# 4  Neutered Male        2 years  Lhasa Apso/Miniature Poodle          Tan

# %%
#Let's take a look at the last rows of data
pTrain.tail()
# Out:
#       AnimalID  Name            DateTime OutcomeType AnimalType  \
# 26724  A702446   NaN 2015-05-14 11:56:00    Transfer        Cat
# 26725  A718934   NaN 2016-01-20 18:59:00    Transfer        Cat
# 26726  A698128  Zeus 2015-03-09 13:33:00    Adoption        Dog
# 26727  A677478   NaN 2014-04-27 12:22:00    Transfer        Cat
# 26728  A706629   NaN 2015-07-02 09:00:00    Transfer        Cat
#
#       SexuponOutcome AgeuponOutcome                    Breed  \
# 26724    Intact Male        1 month   Domestic Shorthair Mix
# 26725  Spayed Female       3 months   Domestic Shorthair Mix
# 26726  Neutered Male        4 years  Old English Bulldog Mix
# 26727    Intact Male        4 weeks   Domestic Shorthair Mix
# 26728    Intact Male         1 year   Domestic Shorthair Mix
#
#                    Color
# 26724  Brown Tabby/White
# 26725        Brown Tabby
# 26726          White/Tan
# 26727              Black
# 26728  Brown Tabby/White

# %%
#Check out to see what format columns are in
pTrain.dtypes
# Out:
# AnimalID                  object
# Name                      object
# DateTime          datetime64[ns]
# OutcomeType               object
# AnimalType                object
# SexuponOutcome            object
# AgeuponOutcome            object
# Breed                     object
# Color                     object
# dtype: object

# %%
#Let's get an idea of how big this data set is
(numRows, numColumns) = pTrain.shape
print numRows
print numColumns
# Out:
# 26729
# 9

# %%
#Lets get a sense of how many unique value for each feature
print "Number of unique Animal IDs: " , pTrain.AnimalID.nunique()
print "Number of unique Names: " , pTrain.Name.nunique()
print "Number of unique Outcome Types: " , pTrain.OutcomeType.nunique()
print "Number of unique Animal Types: " , pTrain.AnimalType.nunique()
print "Number of unique Sex Upon Outcomes: " , pTrain.SexuponOutcome.nunique()
print "Number of unique Age Upon Outcomes: " , pTrain.AgeuponOutcome.nunique()
print "Number of unique Breed Upon Outcomes: " , pTrain.Breed.nunique()
# Out:
# Number of unique Animal IDs:  26729
# Number of unique Names:  6374
# Number of unique Outcome Types:  5
# Number of unique Animal Types:  2
# Number of unique Sex Upon Outcomes:  5
# Number of unique Age Upon Outcomes:  44
# Number of unique Breed Upon Outcomes:  1380

# %%
# lets see how many cells have a name filled in; 
pTrain.isnull().sum()
# Out:
# AnimalID             0
# Name              7691
# DateTime             0
# OutcomeType          0
# AnimalType           0
# SexuponOutcome       0
# AgeuponOutcome       0
# Breed                0
# Color                0
# dtype: int64

# %%
#since 30% of cells don't have names let's get rid of the Name column
del pTrain["Name"]

# %%
pTrain["month"] = pTrain.DateTime.dt.month

# %%
#Let's First concentrate on Animal types and what exactly they are
pTrain.AnimalType.unique()
# Out:
# array(['Dog', 'Cat'], dtype=object)

# %%
#Let's now work on converting our categorical target into a number
# The results shows that there are as many cats and dogs combined as Animal Ids and total rows
pTrain.AnimalType.value_counts()
# Out:
# Dog    15595
# Cat    11134
# Name: AnimalType, dtype: int64

# %%
pTrain["Animal_Type"] = (pTrain.AnimalType=="Cat").astype(int)
pTrain.Animal_Type.value_counts()
#So we have developed a coding where Dog = 0 ~60% and Cat = 1 ~40%
# Out:
# 0    15595
# 1    11134
# Name: Animal_Type, dtype: int64

# %%
#Lets check that this is working
pTrain.tail()
# Out:
#       AnimalID  Name            DateTime OutcomeType AnimalType  \
# 26724  A702446   NaN 2015-05-14 11:56:00    Transfer        Cat
# 26725  A718934   NaN 2016-01-20 18:59:00    Transfer        Cat
# 26726  A698128  Zeus 2015-03-09 13:33:00    Adoption        Dog
# 26727  A677478   NaN 2014-04-27 12:22:00    Transfer        Cat
# 26728  A706629   NaN 2015-07-02 09:00:00    Transfer        Cat
#
#       SexuponOutcome AgeuponOutcome                    Breed  \
# 26724    Intact Male        1 month   Domestic Shorthair Mix
# 26725  Spayed Female       3 months   Domestic Shorthair Mix
# 26726  Neutered Male        4 years  Old English Bulldog Mix
# 26727    Intact Male        4 weeks   Domestic Shorthair Mix
# 26728    Intact Male         1 year   Domestic Shorthair Mix
#
#                    Color  month  Animal_Type
# 26724  Brown Tabby/White      5            1
# 26725        Brown Tabby      1            1
# 26726          White/Tan      3            0
# 26727              Black      4            1
# 26728  Brown Tabby/White      7            1

# %%
#Great! Now lets work on Breed using binary encoding:
#Step 1 Let's encode it
ce.BinaryEncoder(pTrain[["Breed"]])
# Out:
# BinaryEncoder(cols=None, drop_invariant=False, return_df=True,
#        verbose=                                       Breed
# 0                      Shetland Sheepdog Mix
# 1                     Domestic Shorthair Mix
# 2                               Pit Bull Mix
# 3                     Domestic Shorthair Mix
# 4                Lhasa Apso/Miniature Poodle
# 26722         Cat        5 months      8            1
# 26723         Dog         6 years      1            0
# 26724         Cat         1 month      5            1
# 26725         Cat        3 months      1            1
# 26726         Dog         4 years      3            0
# 26727         Cat         4 weeks      4            1
# 26728         Cat          1 year      7            1
#
# [26729 rows x 30 columns]

# %%
#Let's first concentrate on Outcome types and what exactly they are
pTrain.OutcomeType.unique()
# Out:
# array(['Return_to_owner', 'Euthanasia', 'Adoption', 'Transfer', 'Died'], dtype=object)

# %%
le = LabelEncoder()

# %%
#Let's get an array of numbers for Outcome type
le.fit_transform(pTrain.OutcomeType)
# Out:
# array([3, 2, 0, ..., 0, 4, 4])

# %%
#Let's make a new column
pTrain["newOutCome"]=le.fit_transform(pTrain.OutcomeType)

# %%
pTrain.head()
# Out:
#   AnimalID            DateTime      OutcomeType AnimalType SexuponOutcome  \
# 0  A671945 2014-02-12 18:22:00  Return_to_owner        Dog  Neutered Male
# 1  A656520 2013-10-13 12:44:00       Euthanasia        Cat  Spayed Female
# 2  A686464 2015-01-31 12:28:00         Adoption        Dog  Neutered Male
# 3  A683430 2014-07-11 19:09:00         Transfer        Cat    Intact Male
# 4  A667013 2013-11-15 12:52:00         Transfer        Dog  Neutered Male
#
#   AgeuponOutcome                        Breed        Color  month  \
# 0         1 year        Shetland Sheepdog Mix  Brown/White      2
# 1         1 year       Domestic Shorthair Mix  Cream Tabby     10
# 2        2 years                 Pit Bull Mix   Blue/White      1
# 3        3 weeks       Domestic Shorthair Mix   Blue Cream      7
# 4        2 years  Lhasa Apso/Miniature Poodle          Tan     11
#
#    Animal_Type  newOutCome
# 0            0           3
# 1            1           2
# 2            0           0
# 3            1           4
# 4            0           4

# %%
#binaryenc.corr()

# %%
pTrain.newOutCome.value_counts()
#Key 0 = Adoption 40%; 1= Died <1%; 2 = Euthanasia 6%; 3 = Return to Owner 18%; 4= Transfer 35%
# Out:
# 0    10769
# 4     9422
# 3     4786
# 2     1555
# 1      197
# Name: newOutCome, dtype: int64

# %%
logreg = LogisticRegression(C=1e9)
feature_cols = ['Animal_Type',"converted_age", "month"]
X = pTrain[feature_cols]
y = pTrain.newOutCome
logreg.fit(X, y)
outcome_pred_class_log = logreg.predict(X)

# %%
from sklearn import metrics

# %%
X_train,X_test,y_train, y_test = train_test_split(X,y,test_size=0.3)
y_test_pred = logreg.predict(X_test)
print "Test set accuracy of LR model: ", metrics.accuracy_score(y_test, y_test_pred)
# Out:
#  Test set accuracy of LR model:  0.481980296795

# %%
#compute null accuracy manually
#print "null accuracy on test set: ", y_test_pred.mean()

# %%
print "Classification Report: \n" , metrics.classification_report(y_test,y_test_pred)
# Out:
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.46      0.53      0.49      3202
#           1       0.00      0.00      0.00        57
#           2       0.32      0.02      0.04       470
#           3       0.46      0.31      0.37      1419
#           4       0.51      0.59      0.55      2871
#
# avg / total       0.47      0.48      0.46      8019

# %%
#lr probabilities per category for first five samples
#predicted_probs_logreg = logreg.predict_proba(X_test).round(3)
#predictions_logreg = logreg.predict(X_test)

#print "Logistic Regression predicted probabilities for first five samples in test set:\n",predicted_probs_logreg[:5]
#print "Logistic Regression predictions for first five samples in test set:\n",predictions_logreg[:5]
y_test_logreg_df = pd.DataFrame(
    np.concatenate((
        predicted_probs_logreg,predictions_logreg.reshape((predictions_logreg.shape[0],-1)),
        y_test.reshape((y_test.shape[0],-1))),axis=1
    ),
    columns = ["class_0","class_1","class_2", "class_3","class_4","predicted","actual"])

y_test_logreg_df.head()
# Out:
#    class_0  class_1  class_2  class_3  class_4  predicted  actual
# 0    0.401    0.013    0.051    0.033    0.502        4.0     0.0
# 1    0.369    0.014    0.067    0.047    0.503        4.0     4.0
# 2    0.485    0.004    0.032    0.180    0.299        0.0     4.0
# 3    0.459    0.004    0.036    0.201    0.300        0.0     0.0
# 4    0.396    0.003    0.059    0.317    0.226        0.0     4.0

# %%
data = np.concatenate((
        predicted_probs_logreg,predictions_logreg.reshape((predictions_logreg.shape[0],-1)),
        y_test.reshape((y_test.shape[0],-1))),axis=1
    )

# %%
pd.DataFrame(data,columns=)
# Out:
#           0      1      2      3      4    5    6
# 0     0.401  0.013  0.051  0.033  0.502  4.0  0.0
# 1     0.369  0.014  0.067  0.047  0.503  4.0  4.0
# 2     0.485  0.004  0.032  0.180  0.299  0.0  4.0
# 3     0.459  0.004  0.036  0.201  0.300  0.0  0.0
# 4     0.396  0.003  0.059  0.317  0.226  0.0  4.0
# 5     0.394  0.015  0.048  0.031  0.513  4.0  3.0
# 6     0.188  0.002  0.127  0.550  0.133  3.0  3.0
# 7     0.416  0.013  0.047  0.029  0.496  4.0  0.0
# 8     0.447  0.003  0.044  0.241  0.265  0.0  2.0
# 9     0.497  0.004  0.032  0.178  0.290  0.0  4.0
# 10    0.391  0.014  0.051  0.034  0.510  4.0  4.0
# 11    0.188  0.002  0.127  0.550  0.133  3.0  0.0
# 12    0.407  0.013  0.048  0.030  0.501  4.0  0.0
# 13    0.353  0.003  0.069  0.363  0.213  3.0  3.0
# 14    0.482  0.004  0.032  0.181  0.301  0.0  0.0
# 15    0.397  0.013  0.055  0.036  0.498  4.0  4.0
# 16    0.473  0.004  0.037  0.205  0.281  0.0  0.0
# 17    0.450  0.003  0.044  0.239  0.264  0.0  0.0
# 18    0.466  0.004  0.036  0.201  0.294  0.0  4.0
# 19    0.265  0.010  0.181  0.149  0.396  4.0  2.0
# 20    0.490  0.004  0.033  0.184  0.289  0.0  4.0
# 21    0.411  0.013  0.047  0.030  0.499  4.0  0.0
# 22    0.385  0.014  0.056  0.037  0.508  4.0  1.0
# 23    0.405  0.014  0.046  0.029  0.506  4.0  4.0
# 24    0.183  0.002  0.140  0.566  0.110  3.0  3.0
# 25    0.413  0.003  0.051  0.282  0.251  0.0  0.0
# 26    0.427  0.004  0.044  0.248  0.276  0.0  4.0
# 27    0.337  0.003  0.069  0.371  0.220  3.0  0.0
# 28    0.454  0.004  0.038  0.212  0.293  0.0  3.0
# 29    0.116  0.001  0.187  0.616  0.079  3.0  3.0
# ...     ...    ...    ...    ...    ...  ...  ...
# 7989  0.402  0.014  0.046  0.030  0.507  4.0  4.0
# 7990  0.402  0.013  0.052  0.033  0.500  4.0  4.0
# 7991  0.175  0.002  0.141  0.570  0.114  3.0  3.0
# 7992  0.404  0.014  0.047  0.030  0.505  4.0  0.0
# 7993  0.490  0.004  0.032  0.178  0.296  0.0  4.0
# 7994  0.496  0.004  0.032  0.176  0.292  0.0  0.0
# 7995  0.447  0.003  0.044  0.241  0.265  0.0  4.0
# 7996  0.412  0.013  0.046  0.029  0.500  4.0  4.0
# 7997  0.350  0.003  0.069  0.365  0.214  3.0  3.0
# 7998  0.501  0.003  0.032  0.174  0.289  0.0  0.0
# 7999  0.410  0.013  0.046  0.029  0.502  4.0  4.0
# 8000  0.298  0.002  0.089  0.440  0.172  3.0  0.0
# 8001  0.405  0.014  0.046  0.030  0.505  4.0  4.0
# 8002  0.416  0.013  0.047  0.029  0.496  4.0  0.0
# 8003  0.467  0.004  0.037  0.204  0.288  0.0  0.0
# 8004  0.490  0.004  0.032  0.178  0.296  0.0  4.0
# 8005  0.379  0.015  0.056  0.038  0.512  4.0  3.0
# 8006  0.417  0.012  0.047  0.030  0.493  4.0  4.0
# 8007  0.418  0.012  0.047  0.029  0.494  4.0  0.0
# 8008  0.436  0.004  0.044  0.245  0.271  0.0  3.0
# 8009  0.385  0.014  0.056  0.037  0.508  4.0  4.0
# 8010  0.404  0.003  0.052  0.285  0.255  0.0  0.0
# 8011  0.385  0.013  0.066  0.045  0.491  4.0  0.0
# 8012  0.405  0.013  0.053  0.034  0.495  4.0  4.0
# 8013  0.366  0.012  0.080  0.056  0.485  4.0  4.0
# 8014  0.479  0.003  0.037  0.202  0.278  0.0  3.0
# 8015  0.416  0.013  0.047  0.029  0.496  4.0  0.0
# 8016  0.473  0.004  0.037  0.205  0.281  0.0  2.0
# 8017  0.396  0.015  0.046  0.030  0.513  4.0  4.0
# 8018  0.456  0.003  0.043  0.237  0.260  0.0  0.0
#
# [8019 rows x 7 columns]

# %%
#predicted_probs_logreg.shape
#predictions_logreg.reshape((predictions_logreg.shape[0],-1)).shape
y_test.reshape((y_test.shape[0],-1)).shape
# Out:
# (8019, 1)

# %%
y_test.value_counts()
# Out:
# 0    3186
# 4    2853
# 3    1460
# 2     467
# 1      53
# Name: newOutCome, dtype: int64

# %%
logreg.fit(X_train, y_train)
metrics.confusion_matrix(y_test,logreg.predict(X_test))
# Out:
# array([[1708,    0,   13,  211, 1272],
#        [   8,    0,    1,    4,   33],
#        [ 186,    0,   14,   87,  209],
#        [ 860,    0,   12,  420,  152],
#        [ 980,    0,    9,  160, 1680]])

# %%
np.mean(cross_val_score(logreg,X,y,cv=10,scoring="accuracy"))
# Out:
# 0.47461778644854091

# %%
feature_cols = ['Animal_Type',"converted_age", "month"]
X_2 = pTrain[feature_cols]
y_2 = pTrain.newOutCome
X_train,X_test,y_train,y_test = train_test_split(X_2,y_2,test_size=0.3)

# %%
#Random forest of 500 "trees" or estimators
rf = RandomForestRegressor(n_estimators=500, bootstrap=True, oob_score=True, random_state=12)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

#print "Random Forest RMSE:",np.sqrt(mean_squared_error(y_train,y_pred_rf))
print "Random Forest RMSE:",np.sqrt(mean_squared_error(y_test,y_pred_rf))
# Out:
# Random Forest RMSE: 1.62290243505

# %%
#changing AgeUponOutcome column to weeks Step 1 parse at the "string numbers
pTrain["age_new"] = pTrain.AgeuponOutcome.str.split(" ")

# %%
pTrain.AgeuponOutcome.value_counts()
# Out:
# 1 year       3969
# 2 years      3742
# 2 months     3397
# 3 years      1823
# 1 month      1281
# 3 months     1277
# 4 years      1071
# 5 years       992
# 4 months      888
# 6 years       670
# 3 weeks       659
# 5 months      652
# 6 months      588
# 8 years       536
# 7 years       531
# 2 weeks       529
# 10 months     457
# 10 years      446
# 8 months      402
# 4 weeks       334
# 9 years       288
# 7 months      288
# 1 weeks       269
# 12 years      234
# 9 months      224
# 11 months     166
# 13 years      143
# 11 years      126
# 3 days        109
# 2 days         99
# 14 years       97
# 15 years       85
# 1 day          66
# 1 week         66
# 6 days         50
# 4 days         50
# 16 years       36
# 5 days         24
# 0 years        22
# 17 years       17
# 5 weeks        11
# 18 years       10
# 19 years        3
# 20 years        2
# Name: AgeuponOutcome, dtype: int64

# %%
def parse_age_outcome(x):
    if x[1] == "days":
        return int(x[0])
    elif x[1] == "weeks":
        return int(x[0])*7
    elif x[1] == "year" or x[1] == "years":
        return int(x[0]) * 365
    elif x[1] == "month" or x[1] == "months":
        return int(x[0]) * 30
    else:
        return int(x[0])

# %%
pTrain["converted_age"] = pTrain.age_new.map(lambda x: parse_age_outcome(x))

# %%
pTrain.converted_age.value_counts()
# Out:
# 365     3969
# 730     3742
# 60      3397
# 1095    1823
# 30      1281
# 90      1277
# 1460    1071
# 1825     992
# 120      888
# 2190     670
# 21       659
# 150      652
# 180      588
# 2920     536
# 2555     531
# 14       529
# 300      457
# 3650     446
# 240      402
# 28       334
# 3285     288
# 210      288
# 7        269
# 4380     234
# 270      224
# 330      166
# 4745     143
# 1        132
# 4015     126
# 3        109
# 2         99
# 5110      97
# 5475      85
# 6         50
# 4         50
# 5840      36
# 5         24
# 0         22
# 6205      17
# 35        11
# 6570      10
# 6935       3
# 7300       2
# Name: converted_age, dtype: int64

# %%
monthGroups = pTrain.groupby("month")
monthGroupsSizes = monthGroups.size()
print "The month with the most activity is:"
print monthGroupsSizes[monthGroupsSizes==monthGroupsSizes.max()]
# Out:
# The month with the most activity is:
# month
# 10    2881
# dtype: int64

# %%
monthGroups = pTrain.groupby("month")
monthGroupsSizes = monthGroups.size()
print "The month with the least activity is:"
print monthGroupsSizes[monthGroupsSizes==monthGroupsSizes.min()]
# Out:
# The month with the most activity is:
# month
# 3    1498
# dtype: int64
